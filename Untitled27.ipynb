# %% [markdown]
# <a href="https://colab.research.google.com/github/MWANIKID/PhD-Research-files/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()  # Upload BOTH: Bitcoin_data.csv and Tesla_stock.csv
# Out:
#      <input type="file" id="files-49ce2073-9c85-464b-8021-25575ba0cc54" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49ce2073-9c85-464b-8021-25575ba0cc54">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os

# ✅ Ensure figures directory exists
os.makedirs("figures", exist_ok=True)

# 📂 Load data (already done)
btc = pd.read_csv("Bitcoin_data.csv")
btc['Date'] = pd.to_datetime(btc['Date'], dayfirst=True)
btc.set_index('Date', inplace=True)

# 📆 Filter Period 1
btc = btc.loc['2016-01-01':'2019-08-31', ['Close', 'Volume']].dropna()
btc['log_close'] = np.log(btc['Close'])
btc['log_volume'] = np.log(btc['Volume'] + 1)

# ✂️ 70/20/10 split
n = len(btc)
train_end = int(n * 0.7)
val_end = int(n * 0.9)

train_y = btc['log_close'][:train_end]
val_y = btc['log_close'][train_end:val_end]
val_dates = val_y.index

train_exog = btc['log_volume'][:train_end]
val_exog = btc['log_volume'][train_end:val_end]

# 🧠 History setup
history_y = train_y.tolist()
history_exog = train_exog.tolist()
pred_all = []
pred_index = []

# 🔁 7-Day Rolling Forecast
step = 7
for i in range(0, len(val_y) - step, step):
    model = ARIMA(history_y, order=(9,1,6), exog=history_exog).fit()
    future_exog = val_exog.iloc[i:i+step].values.reshape(-1, 1)
    forecast = model.forecast(steps=step, exog=future_exog)
    pred_all.extend(forecast)
    pred_index.extend(val_dates[i:i+step])
    history_y.extend(val_y.iloc[i:i+step].tolist())
    history_exog.extend(val_exog.iloc[i:i+step].tolist())

# ⬅️ Invert log
pred_exp = np.exp(pred_all)
val_actual = np.exp(val_y.loc[pred_index])

# 📊 Evaluation
rmse = np.sqrt(mean_squared_error(val_actual, pred_exp))
mae = mean_absolute_error(val_actual, pred_exp)
print(f"📈 Period 1 – ARIMA(9,1,6) + Volume (7-Day): RMSE = {rmse:.2f}, MAE = {mae:.2f}")

# 📈 Plot (fixed)
plt.figure(figsize=(14,5))
plt.plot(val_y.index, np.exp(val_y.values), label="Actual", color='blue')
plt.plot(pred_index, pred_exp, label="7-Day Forecast", color='orange', linestyle='--')
plt.title("Bitcoin Period 1 – ARIMA(9,1,6) + Volume (7-Day Rolling Forecast)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("figures/bitcoin_period1_arima916_volume_7day.png")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os

# ✅ Load Data
btc = pd.read_csv("Bitcoin_data.csv")
btc['Date'] = pd.to_datetime(btc['Date'], dayfirst=True)
btc.set_index('Date', inplace=True)

# 📆 Filter Period 2
btc = btc.loc['2019-09-01':'2023-03-31', ['Close', 'Volume']].dropna()
btc['log_close'] = np.log(btc['Close'])
btc['log_volume'] = np.log(btc['Volume'] + 1)

# ✂️ 70/20/10 split
n = len(btc)
train_end = int(n * 0.7)
val_end = int(n * 0.9)

train_y = btc['log_close'][:train_end]
val_y = btc['log_close'][train_end:val_end]
val_dates = val_y.index

train_exog = btc['log_volume'][:train_end]
val_exog = btc['log_volume'][train_end:val_end]

# 🧠 Rolling forecast setup
history_y = train_y.tolist()
history_exog = train_exog.tolist()
pred_all = []
pred_index = []

# 🔁 7-Day Rolling Forecast
step = 7
for i in range(0, len(val_y) - step, step):
    model = ARIMA(history_y, order=(9,1,6), exog=history_exog).fit()
    future_exog = val_exog.iloc[i:i+step].values.reshape(-1, 1)
    forecast = model.forecast(steps=step, exog=future_exog)
    pred_all.extend(forecast)
    pred_index.extend(val_dates[i:i+step])
    history_y.extend(val_y.iloc[i:i+step].tolist())
    history_exog.extend(val_exog.iloc[i:i+step].tolist())

# ⬅️ Invert log
pred_exp = np.exp(pred_all)
val_actual = np.exp(val_y.loc[pred_index])

# 📊 Evaluation
rmse = np.sqrt(mean_squared_error(val_actual, pred_exp))
mae = mean_absolute_error(val_actual, pred_exp)
print(f"📈 Period 2 – ARIMA(9,1,6) + Volume (7-Day): RMSE = {rmse:.2f}, MAE = {mae:.2f}")

# 📈 Plot
plt.figure(figsize=(14,5))
plt.plot(val_y.index, np.exp(val_y.values), label="Actual", color='blue')
plt.plot(pred_index, pred_exp, label="7-Day Forecast", color='orange', linestyle='--')
plt.title("Bitcoin Period 2 – ARIMA(9,1,6) + Volume (7-Day Rolling Forecast)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
os.makedirs("figures", exist_ok=True)
plt.savefig("figures/bitcoin_period2_arima916_volume_7day.png")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os

# ✅ Load Data
btc = pd.read_csv("Bitcoin_data.csv")
btc['Date'] = pd.to_datetime(btc['Date'], dayfirst=True)
btc.set_index('Date', inplace=True)

# 📆 Filter Period 3
btc = btc.loc['2016-01-01':'2023-03-31', ['Close', 'Volume']].dropna()
btc['log_close'] = np.log(btc['Close'])
btc['log_volume'] = np.log(btc['Volume'] + 1)

# ✂️ 70/20/10 split
n = len(btc)
train_end = int(n * 0.7)
val_end = int(n * 0.9)

train_y = btc['log_close'][:train_end]
val_y = btc['log_close'][train_end:val_end]
val_dates = val_y.index

train_exog = btc['log_volume'][:train_end]
val_exog = btc['log_volume'][train_end:val_end]

# 🧠 Forecast setup
history_y = train_y.tolist()
history_exog = train_exog.tolist()
pred_all = []
pred_index = []

# 🔁 7-Day Rolling Forecast
step = 7
for i in range(0, len(val_y) - step, step):
    model = ARIMA(history_y, order=(9,1,6), exog=history_exog).fit()
    future_exog = val_exog.iloc[i:i+step].values.reshape(-1, 1)
    forecast = model.forecast(steps=step, exog=future_exog)
    pred_all.extend(forecast)
    pred_index.extend(val_dates[i:i+step])
    history_y.extend(val_y.iloc[i:i+step].tolist())
    history_exog.extend(val_exog.iloc[i:i+step].tolist())

# ⬅️ Invert log
pred_exp = np.exp(pred_all)
val_actual = np.exp(val_y.loc[pred_index])

# 📊 Evaluation
rmse = np.sqrt(mean_squared_error(val_actual, pred_exp))
mae = mean_absolute_error(val_actual, pred_exp)
print(f"📈 Period 3 – ARIMA(9,1,6) + Volume (7-Day): RMSE = {rmse:.2f}, MAE = {mae:.2f}")

# 📈 Plot
plt.figure(figsize=(14,5))
plt.plot(val_y.index, np.exp(val_y.values), label="Actual", color='blue')
plt.plot(pred_index, pred_exp, label="7-Day Forecast", color='orange', linestyle='--')
plt.title("Bitcoin Period 3 – ARIMA(9,1,6) + Volume (7-Day Rolling Forecast)")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
os.makedirs("figures", exist_ok=True)
plt.savefig("figures/bitcoin_period3_arima916_volume_7day.png")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
rmse_p1 = 1345.23
mae_p1 = 1021.87

# %%
rmse_p2 = ...   # use your printed RMSE
mae_p2 = ...
rmse_p3 = ...
mae_p3 = ...

# %%
# Replace these with the actual printed results from your Colab outputs:
rmse_p1 = 1345.23
mae_p1 = 1021.87

rmse_p2 = 1784.65
mae_p2 = 1425.50

rmse_p3 = 1623.48
mae_p3 = 1310.29

# %%
summary_df = pd.DataFrame({
    "Period": ["Period 1 (2016–2019)", "Period 2 (2019–2023)", "Period 3 (2016–2023)"],
    "RMSE": [rmse_p1, rmse_p2, rmse_p3],
    "MAE": [mae_p1, mae_p2, mae_p3]
})

summary_df["RMSE"] = summary_df["RMSE"].apply(lambda x: f"{x:,.2f}")
summary_df["MAE"] = summary_df["MAE"].apply(lambda x: f"{x:,.2f}")

print("📈 Forecast Accuracy Summary (ARIMA(9,1,6) + Volume, 7-Day Horizon):")
display(summary_df)
# Out:
# 📈 Forecast Accuracy Summary (ARIMA(9,1,6) + Volume, 7-Day Horizon):
#                  Period      RMSE       MAE
# 0  Period 1 (2016–2019)  1,345.23  1,021.87
# 1  Period 2 (2019–2023)  1,784.65  1,425.50
# 2  Period 3 (2016–2023)  1,623.48  1,310.29

# %%
# 📝 Save the summary to CSV
summary_df.to_csv("bitcoin_arima916_volume_7day_summary.csv", index=False)

# 📥 Download directly to your browser
from google.colab import files
files.download("bitcoin_arima916_volume_7day_summary.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os
from google.colab import files

# 📂 Load Tesla data
tesla = pd.read_csv("Tesla_stock.csv")
tesla['Date'] = pd.to_datetime(tesla['Date'], dayfirst=True)
tesla.set_index('Date', inplace=True)

# ✅ Define periods
periods = {
    "Period 1": ('2016-01-01', '2019-08-31'),
    "Period 2": ('2019-09-01', '2023-03-31'),
    "Period 3": ('2016-01-01', '2023-03-31')
}

results = []

# 🔁 Loop over each period
for label, (start, end) in periods.items():
    print(f"\n🚀 Running {label} for Tesla...")

    df = tesla.loc[start:end, ['Close', 'Volume']].dropna().copy()
    df['log_close'] = np.log(df['Close'])
    df['log_volume'] = np.log(df['Volume'] + 1)

    # 70/20/10 split
    n = len(df)
    train_end = int(n * 0.7)
    val_end = int(n * 0.9)

    train_y = df['log_close'][:train_end]
    val_y = df['log_close'][train_end:val_end]
    val_dates = val_y.index

    train_exog = df['log_volume'][:train_end]
    val_exog = df['log_volume'][train_end:val_end]

    # Setup
    history_y = train_y.tolist()
    history_exog = train_exog.tolist()
    pred_all = []
    pred_index = []

    # 7-day rolling forecast
    step = 7
    for i in range(0, len(val_y) - step, step):
        model = ARIMA(history_y, order=(9,1,6), exog=history_exog).fit()
        future_exog = val_exog.iloc[i:i+step].values.reshape(-1, 1)
        forecast = model.forecast(steps=step, exog=future_exog)
        pred_all.extend(forecast)
        pred_index.extend(val_dates[i:i+step])
        history_y.extend(val_y.iloc[i:i+step].tolist())
        history_exog.extend(val_exog.iloc[i:i+step].tolist())

    # Evaluation
    pred_exp = np.exp(pred_all)
    val_actual = np.exp(val_y.loc[pred_index])
    rmse = np.sqrt(mean_squared_error(val_actual, pred_exp))
    mae = mean_absolute_error(val_actual, pred_exp)
    print(f"📊 {label}: RMSE = {rmse:.2f}, MAE = {mae:.2f}")

    # Save for summary
    results.append((label, rmse, mae))

    # Plot
    plt.figure(figsize=(14,5))
    plt.plot(val_y.index, np.exp(val_y.values), label="Actual", color='blue')
    plt.plot(pred_index, pred_exp, label="7-Day Forecast", color='orange', linestyle='--')
    plt.title(f"Tesla {label} – ARIMA(9,1,6) + Volume (7-Day Rolling Forecast)")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    # Save plot
    os.makedirs("figures", exist_ok=True)
    plot_path = f"figures/tesla_{label.replace(' ', '_').lower()}_arima916_volume_7day.png"
    plt.savefig(plot_path)
    plt.show()

# 📋 Create summary
summary_df = pd.DataFrame(results, columns=["Period", "RMSE", "MAE"])
summary_df["RMSE"] = summary_df["RMSE"].apply(lambda x: f"{x:,.2f}")
summary_df["MAE"] = summary_df["MAE"].apply(lambda x: f"{x:,.2f}")

# 💾 Save summary
summary_csv = "tesla_arima916_volume_7day_summary.csv"
summary_df.to_csv(summary_csv, index=False)
files.download(summary_csv)

# Display
print("\n✅ Tesla Forecast Summary:")
display(summary_df)
# Out:
# 🚀 Running Period 1 for Tesla...
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
from google.colab import files
files.download("tesla_arima916_volume_7day_summary.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os
from google.colab import files

# 📂 Load Tesla data
tesla = pd.read_csv("Tesla_stock.csv")
tesla['Date'] = pd.to_datetime(tesla['Date'], dayfirst=True)
tesla.set_index('Date', inplace=True)

# ✅ Define periods
periods = {
    "Period 1": ('2016-01-01', '2019-08-31'),
    "Period 2": ('2019-09-01', '2023-03-31'),
    "Period 3": ('2016-01-01', '2023-03-31')
}

results = []

# 🔁 Loop over periods
for label, (start, end) in periods.items():
    print(f"\n🚀 Running {label} for Tesla (1-Day Forecast)...")

    df = tesla.loc[start:end, ['Close', 'Volume']].dropna().copy()
    df['log_close'] = np.log(df['Close'])
    df['log_volume'] = np.log(df['Volume'] + 1)

    # 70/20/10 split
    n = len(df)
    train_end = int(n * 0.7)
    val_end = int(n * 0.9)

    train_y = df['log_close'][:train_end]
    val_y = df['log_close'][train_end:val_end]
    val_dates = val_y.index

    train_exog = df['log_volume'][:train_end]
    val_exog = df['log_volume'][train_end:val_end]

    # Setup
    history_y = train_y.tolist()
    history_exog = train_exog.tolist()
    pred_all = []
    pred_index = []

    # 🔁 1-Day Rolling Forecast
    for i in range(len(val_y)):
        model = ARIMA(history_y, order=(9,1,6), exog=history_exog).fit()
        future_exog = val_exog.iloc[i:i+1].values.reshape(-1, 1)
        forecast = model.forecast(steps=1, exog=future_exog)
        pred_all.append(forecast[0])
        pred_index.append(val_dates[i])
        history_y.append(val_y.iloc[i])
        history_exog.append(val_exog.iloc[i])

    # Evaluate
    pred_exp = np.exp(pred_all)
    val_actual = np.exp(val_y.loc[pred_index])
    rmse = np.sqrt(mean_squared_error(val_actual, pred_exp))
    mae = mean_absolute_error(val_actual, pred_exp)
    print(f"📊 {label}: RMSE = {rmse:.2f}, MAE = {mae:.2f}")
    results.append((label, rmse, mae))

    # Plot
    plt.figure(figsize=(14,5))
    plt.plot(val_y.index, np.exp(val_y.values), label="Actual", color='blue')
    plt.plot(pred_index, pred_exp, label="1-Day Forecast", color='red', linestyle='--')
    plt.title(f"Tesla {label} – ARIMA(9,1,6) + Volume (1-Day Rolling Forecast)")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    os.makedirs("figures", exist_ok=True)
    plot_path = f"figures/tesla_{label.replace(' ', '_').lower()}_arima916_volume_1day.png"
    plt.savefig(plot_path)
    plt.show()

# 📋 Summary Table
summary_df = pd.DataFrame(results, columns=["Period", "RMSE", "MAE"])
summary_df["RMSE"] = summary_df["RMSE"].apply(lambda x: f"{x:,.2f}")
summary_df["MAE"] = summary_df["MAE"].apply(lambda x: f"{x:,.2f}")

# 💾 Save summary
summary_csv = "tesla_arima916_volume_1day_summary.csv"
summary_df.to_csv(summary_csv, index=False)
files.download(summary_csv)

print("\n✅ Tesla 1-Day Forecast Summary:")
display(summary_df)
# Out:
# 🚀 Running Period 1 for Tesla (1-Day Forecast)...
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os
from google.colab import files

# 📂 Load Tesla data
tesla = pd.read_csv("Tesla_stock.csv")
tesla['Date'] = pd.to_datetime(tesla['Date'], dayfirst=True)
tesla.set_index('Date', inplace=True)

# ✅ Define periods and best ARIMA orders
periods = {
    "Period 1": ('2016-01-01', '2019-08-31', (3, 1, 3)),
    "Period 2": ('2019-09-01', '2023-03-31', (8, 1, 8)),
    "Period 3": ('2016-01-01', '2023-03-31', (7, 1, 9))
}

results = []

# 🔁 Loop through periods
for label, (start, end, arima_order) in periods.items():
    print(f"\n🚀 Running {label} Tesla ARIMA{arima_order} (7-Day Forecast)...")

    df = tesla.loc[start:end, ['Close', 'Volume']].dropna().copy()
    df['log_close'] = np.log(df['Close'])
    df['log_volume'] = np.log(df['Volume'] + 1)

    # 70/20/10 split
    n = len(df)
    train_end = int(n * 0.7)
    val_end = int(n * 0.9)

    train_y = df['log_close'][:train_end]
    val_y = df['log_close'][train_end:val_end]
    val_dates = val_y.index

    train_exog = df['log_volume'][:train_end]
    val_exog = df['log_volume'][train_end:val_end]

    history_y = train_y.tolist()
    history_exog = train_exog.tolist()
    pred_all = []
    pred_index = []

    step = 7
    for i in range(0, len(val_y) - step, step):
        model = ARIMA(history_y, order=arima_order, exog=history_exog).fit()
        future_exog = val_exog.iloc[i:i+step].values
        forecast = model.forecast(steps=step, exog=future_exog)
        pred_all.extend(forecast)
        pred_index.extend(val_dates[i:i+step])
        history_y.extend(val_y.iloc[i:i+step])
        history_exog.extend(val_exog.iloc[i:i+step])

    # Evaluation
    pred_exp = np.exp(pred_all)
    val_actual = np.exp(val_y.loc[pred_index])
    rmse = np.sqrt(mean_squared_error(val_actual, pred_exp))
    mae = mean_absolute_error(val_actual, pred_exp)
    print(f"📊 {label}: RMSE = {rmse:.2f}, MAE = {mae:.2f}")
    results.append((label, rmse, mae))

    # Plot
    plt.figure(figsize=(14,5))
    plt.plot(val_y.index, np.exp(val_y.values), label="Actual", color='blue')
    plt.plot(pred_index, pred_exp, label="7-Day Forecast", color='orange', linestyle='--')
    plt.title(f"Tesla {label} – ARIMA{arima_order} + Volume (7-Day Forecast)")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    os.makedirs("figures", exist_ok=True)
    plot_path = f"figures/tesla_{label.replace(' ', '_').lower()}_arima{arima_order[0]}{arima_order[1]}{arima_order[2]}_volume_7day.png"
    plt.savefig(plot_path)
    plt.show()

# 📋 Summary Table
summary_df = pd.DataFrame(results, columns=["Period", "RMSE", "MAE"])
summary_df["RMSE"] = summary_df["RMSE"].apply(lambda x: f"{x:,.2f}")
summary_df["MAE"] = summary_df["MAE"].apply(lambda x: f"{x:,.2f}")

# 💾 Save summary
summary_csv = "tesla_best_arima_7day_summary.csv"
summary_df.to_csv(summary_csv, index=False)
files.download(summary_csv)

print("\n✅ Tesla 7-Day Forecast Summary:")
display(summary_df)
# Out:
# 🚀 Running Period 1 Tesla ARIMA(3, 1, 3) (7-Day Forecast)...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os
from google.colab import files

# 📂 Load Bitcoin data
btc = pd.read_csv("Bitcoin_data.csv")
btc['Date'] = pd.to_datetime(btc['Date'], dayfirst=True)
btc.set_index('Date', inplace=True)

# ✅ Define periods and best ARIMA orders for Bitcoin
periods = {
    "Period 1": ('2016-01-01', '2019-08-31', (9, 1, 9)),
    "Period 2": ('2019-09-01', '2023-03-31', (9, 1, 6)),
    "Period 3": ('2016-01-01', '2023-03-31', (10, 1, 9))
}

results = []

# 🔁 Loop through periods
for label, (start, end, arima_order) in periods.items():
    print(f"\n🚀 Running {label} Bitcoin ARIMA{arima_order} (7-Day Forecast)...")

    df = btc.loc[start:end, ['Close', 'Volume']].dropna().copy()
    df['log_close'] = np.log(df['Close'])
    df['log_volume'] = np.log(df['Volume'] + 1)

    # 70/20/10 split
    n = len(df)
    train_end = int(n * 0.7)
    val_end = int(n * 0.9)

    train_y = df['log_close'][:train_end]
    val_y = df['log_close'][train_end:val_end]
    val_dates = val_y.index

    train_exog = df['log_volume'][:train_end]
    val_exog = df['log_volume'][train_end:val_end]

    history_y = train_y.tolist()
    history_exog = train_exog.tolist()
    pred_all = []
    pred_index = []

    step = 7
    for i in range(0, len(val_y) - step, step):
        model = ARIMA(history_y, order=arima_order, exog=history_exog).fit()
        future_exog = val_exog.iloc[i:i+step].values
        forecast = model.forecast(steps=step, exog=future_exog)
        pred_all.extend(forecast)
        pred_index.extend(val_dates[i:i+step])
        history_y.extend(val_y.iloc[i:i+step])
        history_exog.extend(val_exog.iloc[i:i+step])

    # Evaluation
    pred_exp = np.exp(pred_all)
    val_actual = np.exp(val_y.loc[pred_index])
    rmse = np.sqrt(mean_squared_error(val_actual, pred_exp))
    mae = mean_absolute_error(val_actual, pred_exp)
    print(f"📊 {label}: RMSE = {rmse:.2f}, MAE = {mae:.2f}")
    results.append((label, rmse, mae))

    # Plot
    plt.figure(figsize=(14,5))
    plt.plot(val_y.index, np.exp(val_y.values), label="Actual", color='blue')
    plt.plot(pred_index, pred_exp, label="7-Day Forecast", color='orange', linestyle='--')
    plt.title(f"Bitcoin {label} – ARIMA{arima_order} + Volume (7-Day Forecast)")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    os.makedirs("figures", exist_ok=True)
    plot_path = f"figures/bitcoin_{label.replace(' ', '_').lower()}_arima{arima_order[0]}{arima_order[1]}{arima_order[2]}_volume_7day.png"
    plt.savefig(plot_path)
    plt.show()

# 📋 Summary Table
summary_df = pd.DataFrame(results, columns=["Period", "RMSE", "MAE"])
summary_df["RMSE"] = summary_df["RMSE"].apply(lambda x: f"{x:,.2f}")
summary_df["MAE"] = summary_df["MAE"].apply(lambda x: f"{x:,.2f}")

# 💾 Save summary
summary_csv = "bitcoin_best_arima_7day_summary.csv"
summary_df.to_csv(summary_csv, index=False)
files.download(summary_csv)

print("\n✅ Bitcoin 7-Day Forecast Summary:")
display(summary_df)
# Out:
# 🚀 Running Period 1 Bitcoin ARIMA(9, 1, 9) (7-Day Forecast)...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os
from google.colab import files

# 📂 Load Bitcoin data
btc = pd.read_csv("Bitcoin_data.csv")  # Make sure to upload this to Colab
btc['Date'] = pd.to_datetime(btc['Date'], dayfirst=True)
btc.set_index('Date', inplace=True)

# ✅ Define periods and best ARIMA orders
periods = {
    "Period 1": ('2016-01-01', '2019-08-31', (9, 1, 9)),
    "Period 2": ('2019-09-01', '2023-03-31', (9, 1, 6)),
    "Period 3": ('2016-01-01', '2023-03-31', (10, 1, 9))
}

results = []

for label, (start, end, arima_order) in periods.items():
    print(f"\n🚀 Running {label} – ARIMA{arima_order} Rolling 7-Day Forecast...")

    df = btc.loc[start:end, ['Close', 'Volume']].dropna().copy()
    df['log_close'] = np.log(df['Close'])
    df['log_volume'] = np.log(df['Volume'] + 1)

    # 70/20/10 split
    n = len(df)
    train_end = int(n * 0.7)
    test_end = int(n * 0.9)

    train_y = df['log_close'][:train_end]
    test_y = df['log_close'][test_end:]
    test_dates = test_y.index

    train_exog = df['log_volume'][:train_end]
    test_exog = df['log_volume'][test_end:]

    history_y = train_y.tolist()
    history_exog = train_exog.tolist()
    pred_all = []
    pred_index = []

    step = 7
    for i in range(0, len(test_y) - step, step):
        model = ARIMA(history_y, order=arima_order, exog=history_exog).fit()
        future_exog = test_exog.iloc[i:i+step].values
        forecast = model.forecast(steps=step, exog=future_exog)
        pred_all.extend(forecast)
        pred_index.extend(test_dates[i:i+step])
        history_y.extend(test_y.iloc[i:i+step])
        history_exog.extend(test_exog.iloc[i:i+step])

    # Evaluation
    pred_exp = np.exp(pred_all)
    actual_exp = np.exp(test_y.loc[pred_index])
    rmse = np.sqrt(mean_squared_error(actual_exp, pred_exp))
    mae = mean_absolute_error(actual_exp, pred_exp)
    print(f"📊 {label}: RMSE = {rmse:.2f}, MAE = {mae:.2f}")
    results.append((label, rmse, mae))

    # Plot
    plt.figure(figsize=(14, 5))
    plt.plot(actual_exp.index, actual_exp.values, label="Expected", color='blue')
    plt.plot(pred_index, pred_exp, label="Predicted", color='red', linestyle='--')
    plt.title(f"Bitcoin {label} – ARIMA{arima_order} Out-of-Sample 7-Day Rolling Forecast")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    os.makedirs("figures", exist_ok=True)
    fig_name = f"figures/bitcoin_{label.replace(' ', '_').lower()}_arima{arima_order[0]}{arima_order[1]}{arima_order[2]}_7day_oos.png"
    plt.savefig(fig_name)
    plt.show()

# Summary Table
summary_df = pd.DataFrame(results, columns=["Period", "RMSE", "MAE"])
summary_df["RMSE"] = summary_df["RMSE"].apply(lambda x: f"{x:,.2f}")
summary_df["MAE"] = summary_df["MAE"].apply(lambda x: f"{x:,.2f}")

# Save & Download
summary_csv = "bitcoin_oos_7day_rolling_summary.csv"
summary_df.to_csv(summary_csv, index=False)
files.download(summary_csv)

print("\n✅ OOS Forecast Summary:")
display(summary_df)
# Out:
# 🚀 Running Period 1 – ARIMA(9, 1, 9) Rolling 7-Day Forecast...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error
import os

# 📂 Load Tesla data
tesla = pd.read_csv("Tesla_stock.csv")
tesla['Date'] = pd.to_datetime(tesla['Date'], dayfirst=True)
tesla.set_index('Date', inplace=True)

# ✅ Define periods and best ARIMA orders for Tesla
periods = {
    "Period 1": ('2016-01-01', '2019-08-31', (3, 1, 3)),
    "Period 2": ('2019-09-01', '2023-03-31', (8, 1, 8)),
    "Period 3": ('2016-01-01', '2023-03-31', (7, 1, 9))
}

results = []

# 🔁 Loop through periods
for label, (start, end, arima_order) in periods.items():
    print(f"\n🚀 Running {label} Tesla ARIMA{arima_order} (7-Day OOS Forecast)...")

    df = tesla.loc[start:end, ['Close', 'Volume']].dropna().copy()
    df['log_close'] = np.log(df['Close'])
    df['log_volume'] = np.log(df['Volume'] + 1)

    # 70/20/10 split
    n = len(df)
    train_end = int(n * 0.9)
    train = df.iloc[:train_end]
    test = df.iloc[train_end:]

    train_y = train['log_close']
    train_exog = train['log_volume']
    test_y = test['log_close']
    test_exog = test['log_volume']
    test_dates = test_y.index

    history_y = train_y.tolist()
    history_exog = train_exog.tolist()
    pred_all = []
    pred_index = []

    step = 7
    for i in range(0, len(test_y) - step, step):
        model = ARIMA(history_y, order=arima_order, exog=history_exog).fit()
        future_exog = test_exog.iloc[i:i+step].values
        forecast = model.forecast(steps=step, exog=future_exog)
        pred_all.extend(forecast)
        pred_index.extend(test_dates[i:i+step])
        history_y.extend(test_y.iloc[i:i+step])
        history_exog.extend(test_exog.iloc[i:i+step])

    # Evaluation
    pred_exp = np.exp(pred_all)
    actual_exp = np.exp(test_y.loc[pred_index])
    rmse = np.sqrt(mean_squared_error(actual_exp, pred_exp))
    mae = mean_absolute_error(actual_exp, pred_exp)
    print(f"📊 {label}: RMSE = {rmse:.2f}, MAE = {mae:.2f}")
    results.append((label, rmse, mae))

    # Plot
    plt.figure(figsize=(14,5))
    plt.plot(actual_exp.index, actual_exp.values, label="Expected", color='blue')
    plt.plot(pred_index, pred_exp, label="Predicted", color='red', linestyle='--')
    plt.title(f"Tesla {label} – ARIMA{arima_order} Out-of-Sample Forecast")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    os.makedirs("figures", exist_ok=True)
    plt.savefig(f"figures/tesla_{label.replace(' ', '_').lower()}_oos_arima{arima_order[0]}{arima_order[1]}{arima_order[2]}.png")
    plt.show()

# 📋 Summary Table
summary_df = pd.DataFrame(results, columns=["Period", "RMSE", "MAE"])
summary_df.to_csv("tesla_oos_arima_best_models.csv", index=False)

from google.colab import files
files.download("tesla_oos_arima_best_models.csv")
# Out:
# 🚀 Running Period 1 Tesla ARIMA(3, 1, 3) (7-Day OOS Forecast)...
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 📊 Period 1: RMSE = 0.94, MAE = 0.76
# 🚀 Running Period 2 Tesla ARIMA(8, 1, 8) (7-Day OOS Forecast)...
# ...
